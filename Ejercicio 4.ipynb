# %% [markdown]
# ## Ejercicio 4

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
import sympy as sp

# Datos proporcionados
x_points = [0, 30, 60, 90]
y_points = [0, 0.5, sqrt(3)/2, 1]

# Función para calcular el polinomio de Lagrange
def lagrange_polynomial(x, x_points, y_points):
    n = len(x_points)
    result = 0

    for i in range(n):
        term = y_points[i]

        for j in range(n):
            if i != j:
                term *= (x - x_points[j]) / (x_points[i] - x_points[j])

        result += term

    return result

# Calcular la expresión algebraica del polinomio de Lagrange
def get_lagrange_expression():
    x = sp.Symbol('x')
    n = len(x_points)
    result = 0

    for i in range(n):
        term = y_points[i]

        for j in range(n):
            if i != j:
                term *= (x - x_points[j]) / (x_points[i] - x_points[j])

        result += term

    # Simplificar y expandir
    result = sp.expand(result)
    return result

# Obtener la expresión algebraica
expr = get_lagrange_expression()
expr_str = str(expr)

# Crear el rango de x para la gráfica
x_range = np.linspace(-10, 100, 1000)

# Calcular los valores del polinomio para cada x
y_range = [lagrange_polynomial(x, x_points, y_points) for x in x_range]

# Crear la gráfica
plt.figure(figsize=(10, 6))

# Graficar el polinomio de Lagrange
plt.plot(x_range, y_range, 'b-', label='Polinomio de Lagrange')

# Graficar los puntos de datos
plt.scatter(x_points, y_points, color='red', s=50, label='Puntos dados')

# Configurar la gráfica
plt.axhline(y=0, color='gray', linestyle='-', alpha=0.3)
plt.axvline(x=0, color='gray', linestyle='-', alpha=0.3)
plt.grid(True, alpha=0.3)
plt.legend()
plt.title('Polinomio de Lagrange para los puntos dados')
plt.xlabel('x')
plt.ylabel('y')

# Añadir el texto del polinomio
plt.figtext(0.5, 0.01, f'P(x) = {expr_str}',
           horizontalalignment='center', fontsize=10,
           bbox={'facecolor': 'white', 'alpha': 0.8, 'pad': 5})

# Mostrar el valor exacto de sqrt(3)/2
sqrt3_2 = sqrt(3)/2
plt.annotate(f'(60, {sqrt3_2:.4f})', xy=(60, sqrt3_2), xytext=(65, sqrt3_2-0.1),
             arrowprops=dict(facecolor='black', shrink=0.05, width=1.5))

plt.ylim(-0.2, 1.2)
plt.show()

# Mostrar el polinomio explícitamente en la consola
print(f"Polinomio de Lagrange: P(x) = {expr_str}")
# Out:
# Polinomio de Lagrange: P(x) = -6.05408712057506e-7*x**3 - 1.99435471456919e-5*x**2 + 0.0178098409218892*x

# %%
# Continuación del código del Ejercicio 4

# Determinar el grado del polinomio
def get_polynomial_degree(expr):
    """Obtiene el grado del polinomio a partir de la expresión simbólica"""
    polynomial = sp.Poly(expr, sp.Symbol('x'))
    return polynomial.degree()

# Obtener el grado del polinomio
polynomial_degree = get_polynomial_degree(expr)

# Actualizar el título de la gráfica para incluir el grado
plt.suptitle(f'Polinomio de Lagrange (Grado {polynomial_degree})', fontsize=14)

# Añadir texto explicativo sobre el grado del polinomio
explanation = (f"El polinomio de Lagrange que pasa por los {len(x_points)} puntos "
               f"tiene grado {polynomial_degree}.\n"
               f"Esto es esperado ya que se interpolan {len(x_points)} puntos.")

plt.figtext(0.5, -0.05, explanation, horizontalalignment='center',
            fontsize=11, bbox={'facecolor': 'lightyellow', 'alpha': 0.8, 'pad': 5})

# También podemos añadir una explicación matemática más detallada
print("\nExplicación del grado del polinomio:")
print(f"Al interpolar {len(x_points)} puntos distintos con un polinomio de Lagrange,")
print(f"el resultado es un polinomio de grado a lo sumo n-1 = {len(x_points)-1}.")
print(f"En este caso, el polinomio resultante es exactamente de grado {polynomial_degree}.")

# Podemos mostrar los coeficientes del polinomio ordenados
poly = sp.Poly(expr, sp.Symbol('x'))
coeffs = poly.all_coeffs()

print("\nCoeficientes del polinomio (de mayor a menor grado):")
for i, coeff in enumerate(coeffs):
    degree = polynomial_degree - i
    if degree > 1:
        print(f"Coeficiente de x^{degree}: {coeff}")
    elif degree == 1:
        print(f"Coeficiente de x: {coeff}")
    else:
        print(f"Término independiente: {coeff}")

# Respuesta a la pregunta planteada
print("\nRespuesta: El polinomio de Lagrange resultante es de grado", polynomial_degree)

# Para visualizar mejor la interpolación, podemos añadir una función que represente
# el seno en grados, ya que los puntos parecen seguir esta función
def sin_degrees(x):
    return np.sin(np.radians(x))

# Añadir esta función a la gráfica para comparar
sin_values = [sin_degrees(x) for x in x_range]
plt.plot(x_range, sin_values, 'g--', alpha=0.6, label='sin(x°)')
plt.legend()

# Actualizar la figura con las nuevas adiciones
plt.tight_layout()
plt.subplots_adjust(bottom=0.2)  # Ajustar espacio para el texto adicional
plt.show()
# Out:
# Explicación del grado del polinomio:
# Al interpolar 4 puntos distintos con un polinomio de Lagrange,
# el resultado es un polinomio de grado a lo sumo n-1 = 3.
# En este caso, el polinomio resultante es exactamente de grado 3.
#
# Coeficientes del polinomio (de mayor a menor grado):
# Coeficiente de x^3: -6.05408712057506E-7
# Coeficiente de x^2: -0.0000199435471456919
# Coeficiente de x: 0.0178098409218892
# Término independiente: 0.0
#
# Respuesta: El polinomio de Lagrange resultante es de grado 3
